# %% [markdown]
# <a href="https://colab.research.google.com/github/zpalevani/AdultIncomeData/blob/main/Adult_Income_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
df = pd.read_csv(url, header=None)  # Adjust header as needed
df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"

# Define column names based on the dataset description
column_names = [
    "age", "workclass", "fnlwgt", "education", "education-num",
    "marital-status", "occupation", "relationship", "race", "sex",
    "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"
]

# Read the CSV file and assign the column names directly
df = pd.read_csv(url, names=column_names, header=None)  # Adjust header as needed

# Display the formatted dataset to the user
# use pandas' display function
display(df) # or df.head() to display the first few rows
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head() # to display the first few rows
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
# Check for missing values in the dataset
missing_values = df.isnull().sum()

# Display missing values for each column
missing_values
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# It seems there are no missing values, but some datasets use placeholders like "?", "NA", or empty strings instead of actual NaN values. To ensure completeness, you can check for these cases with:

# %%
# Check for missing values, including placeholders like "?"
df.replace("?", pd.NA, inplace=True)
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
import pandas as pd

# Define column names based on the dataset description
column_names = [
    "age", "workclass", "education", "education-num",
    "marital-status", "occupation", "relationship", "race", "sex",
    "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"
]

# Download the dataset if it's not already present
import os
if not os.path.exists("adult.data"):
    # !wget https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data

# Load the dataset with the defined headers
# If adult.data is in the same directory as your script:
file_path = "adult.data"
# Or provide the full path to the file if it's in a different location:
# file_path = "/path/to/your/adult.data"

df = pd.read_csv(file_path, names=column_names, sep=",", skipinitialspace=True)

# Convert 'age' column to numeric, handling errors by coercing to NaN
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# Now you can use df in the subsequent lines:
# Change from df["age"] to df["age"] to correctly select the 'age' column
df["age"] = df["age"].fillna(df["age"].median())
# Out:
# --2025-03-16 01:43:25--  https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘adult.data’
#
# adult.data              [   <=>              ]   3.79M  7.68MB/s    in 0.5s
#
# 2025-03-16 01:43:25 (7.68 MB/s) - ‘adult.data’ saved [3974305]

# %%
df["occupation"] = df["occupation"].fillna(df["occupation"].mode()[0])
df["native-country"] = df["native-country"].fillna(df["native-country"].mode()[0])

# %%
df.isnull().sum()
# Out:
# age               32561
# workclass             0
# education             0
# education-num         0
# marital-status        0
# occupation            0
# relationship          0
# race                  0
# sex                   0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country        0
# income                0
# dtype: int64

# %%
print(df["age"].describe())
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: age, dtype: float64

# %%
df["age"] = pd.to_numeric(df["age"], errors="coerce")  # Convert to numeric, setting errors to NaN if needed
print(df["age"].dtype)  # Ensure it's a number
# Out:
# float64

# %%
print(df[df["age"] > 120])  # No realistic human age should be >120
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %% [markdown]
# Fixing the age Column
# To restore the correct values, try the following:
#
# 1. Reload the Dataset (if needed)
# If age is completely incorrect, reload the dataset from the original file:

# %%
import pandas as pd

# Reload dataset
# Update file_path to the correct location of your adult.data file.
# For example, if it's in the current directory with the notebook, use:
file_path = "/content/adult.data"  # or "./adult.data"
# or the full path to the file if it's located elsewhere on your system

column_names = [
    "age", "workclass", "fnlwgt", "education", "education-num",
    "marital-status", "occupation", "relationship", "race", "sex",
    "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"
]
df = pd.read_csv(file_path, names=column_names, sep=",", skipinitialspace=True)

# %% [markdown]
# 2. Ensure age is Numeric

# %%
df["age"] = pd.to_numeric(df["age"], errors="coerce")
print(df["age"].dtype)  # Should be int64 or float64
# Out:
# int64

# %% [markdown]
# 3. Verify the Median Before Imputation
# Check the median value before filling missing values:

# %%
print(df["age"].describe())  # Check realistic values (should be 30-50 range)
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# 4. Correctly Impute Missing age Values
# If missing values exist, replace them with the median correctly:

# %%
df["age"].fillna(df["age"].median(), inplace=True)
# Out:
# <ipython-input-20-8c91363d0247>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].median(), inplace=True)

# %% [markdown]
# 5. Confirm Fix
# Check again to ensure missing values are gone and the values are realistic:

# %%
print(df["age"].describe())  # The median should be reasonable
print(df.isnull().sum())  # Ensure no missing values remain
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64
